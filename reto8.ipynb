# %% [markdown]
# ### ejercicio 1

# %%
range(1, 101) # estableci una lista con un rango del 1 al 100 
c:int = 2 # estableci la variable con 2 para luego hallar la potencia del rango
for n in range(1, 101): # para cada elemento n de la lista del rango previamente establecido
    cuadrado = n ** c #aqui solo calcule el cuadrado para cada elemento de n al cuadrado por la variable establecida
    print("el numero: " + str(n)+ " y su cuadrado es: " + str(cuadrado)) #imprimi el numero y su cuadrado
# Out:
# el numero: 1 y su cuadrado es: 1
# el numero: 2 y su cuadrado es: 4
# el numero: 3 y su cuadrado es: 9
# el numero: 4 y su cuadrado es: 16
# el numero: 5 y su cuadrado es: 25
# el numero: 6 y su cuadrado es: 36
# el numero: 7 y su cuadrado es: 49
# el numero: 8 y su cuadrado es: 64
# el numero: 9 y su cuadrado es: 81
# el numero: 10 y su cuadrado es: 100
# el numero: 11 y su cuadrado es: 121
# el numero: 12 y su cuadrado es: 144
# el numero: 13 y su cuadrado es: 169
# el numero: 14 y su cuadrado es: 196
# el numero: 15 y su cuadrado es: 225
# el numero: 16 y su cuadrado es: 256
# el numero: 17 y su cuadrado es: 289
# el numero: 18 y su cuadrado es: 324
# el numero: 19 y su cuadrado es: 361
# el numero: 20 y su cuadrado es: 400
# el numero: 21 y su cuadrado es: 441
# el numero: 22 y su cuadrado es: 484
# el numero: 23 y su cuadrado es: 529
# el numero: 24 y su cuadrado es: 576
# el numero: 25 y su cuadrado es: 625
# el numero: 26 y su cuadrado es: 676
# el numero: 27 y su cuadrado es: 729
# el numero: 28 y su cuadrado es: 784
# el numero: 29 y su cuadrado es: 841
# el numero: 30 y su cuadrado es: 900
# el numero: 31 y su cuadrado es: 961
# el numero: 32 y su cuadrado es: 1024
# el numero: 33 y su cuadrado es: 1089
# el numero: 34 y su cuadrado es: 1156
# el numero: 35 y su cuadrado es: 1225
# el numero: 36 y su cuadrado es: 1296
# el numero: 37 y su cuadrado es: 1369
# el numero: 38 y su cuadrado es: 1444
# el numero: 39 y su cuadrado es: 1521
# el numero: 40 y su cuadrado es: 1600
# el numero: 41 y su cuadrado es: 1681
# el numero: 42 y su cuadrado es: 1764
# el numero: 43 y su cuadrado es: 1849
# el numero: 44 y su cuadrado es: 1936
# el numero: 45 y su cuadrado es: 2025
# el numero: 46 y su cuadrado es: 2116
# el numero: 47 y su cuadrado es: 2209
# el numero: 48 y su cuadrado es: 2304
# el numero: 49 y su cuadrado es: 2401
# el numero: 50 y su cuadrado es: 2500
# el numero: 51 y su cuadrado es: 2601
# el numero: 52 y su cuadrado es: 2704
# el numero: 53 y su cuadrado es: 2809
# el numero: 54 y su cuadrado es: 2916
# el numero: 55 y su cuadrado es: 3025
# el numero: 56 y su cuadrado es: 3136
# el numero: 57 y su cuadrado es: 3249
# el numero: 58 y su cuadrado es: 3364
# el numero: 59 y su cuadrado es: 3481
# el numero: 60 y su cuadrado es: 3600
# el numero: 61 y su cuadrado es: 3721
# el numero: 62 y su cuadrado es: 3844
# el numero: 63 y su cuadrado es: 3969
# el numero: 64 y su cuadrado es: 4096
# el numero: 65 y su cuadrado es: 4225
# el numero: 66 y su cuadrado es: 4356
# el numero: 67 y su cuadrado es: 4489
# el numero: 68 y su cuadrado es: 4624
# el numero: 69 y su cuadrado es: 4761
# el numero: 70 y su cuadrado es: 4900
# el numero: 71 y su cuadrado es: 5041
# el numero: 72 y su cuadrado es: 5184
# el numero: 73 y su cuadrado es: 5329
# el numero: 74 y su cuadrado es: 5476
# el numero: 75 y su cuadrado es: 5625
# el numero: 76 y su cuadrado es: 5776
# el numero: 77 y su cuadrado es: 5929
# el numero: 78 y su cuadrado es: 6084
# el numero: 79 y su cuadrado es: 6241
# el numero: 80 y su cuadrado es: 6400
# el numero: 81 y su cuadrado es: 6561
# el numero: 82 y su cuadrado es: 6724
# el numero: 83 y su cuadrado es: 6889
# el numero: 84 y su cuadrado es: 7056
# el numero: 85 y su cuadrado es: 7225
# el numero: 86 y su cuadrado es: 7396
# el numero: 87 y su cuadrado es: 7569
# el numero: 88 y su cuadrado es: 7744
# el numero: 89 y su cuadrado es: 7921
# el numero: 90 y su cuadrado es: 8100
# el numero: 91 y su cuadrado es: 8281
# el numero: 92 y su cuadrado es: 8464
# el numero: 93 y su cuadrado es: 8649
# el numero: 94 y su cuadrado es: 8836
# el numero: 95 y su cuadrado es: 9025
# el numero: 96 y su cuadrado es: 9216
# el numero: 97 y su cuadrado es: 9409
# el numero: 98 y su cuadrado es: 9604
# el numero: 99 y su cuadrado es: 9801
# el numero: 100 y su cuadrado es: 10000

# %% [markdown]
# ### ejercicio 2

# %%
range(1, 1000) #estableci el primer listado con un rango de 1 a 999
for n in range(1, 101):  #utilice for para iterar el rango, para cada elemento n
    if n%2 == 0: #<bloque> verifica si el numero es par y lo exceptua
        continue 
    print("el valor i en el ciclo es: " + str(n)) #imprime los valores del primer listado establecido
range(2, 1001) #estableci el segundo listado con un rango de 2 a 1000 
for i in range(2, 1001):     #utilice for para iterar el rango, para cada elemento de i
    if i%2 != 0: #<bloque> verifica si el numero es impar y lo exceptua
        continue
    print("el valor i en el ciclo es: " + str(i)) #imprime los valores del segundo listado establecido
# Out:
# el valor i en el ciclo es: 1
# el valor i en el ciclo es: 3
# el valor i en el ciclo es: 5
# el valor i en el ciclo es: 7
# el valor i en el ciclo es: 9
# el valor i en el ciclo es: 11
# el valor i en el ciclo es: 13
# el valor i en el ciclo es: 15
# el valor i en el ciclo es: 17
# el valor i en el ciclo es: 19
# el valor i en el ciclo es: 21
# el valor i en el ciclo es: 23
# el valor i en el ciclo es: 25
# el valor i en el ciclo es: 27
# el valor i en el ciclo es: 29
# el valor i en el ciclo es: 31
# el valor i en el ciclo es: 33
# el valor i en el ciclo es: 35
# el valor i en el ciclo es: 37
# el valor i en el ciclo es: 39
# el valor i en el ciclo es: 41
# el valor i en el ciclo es: 43
# el valor i en el ciclo es: 45
# el valor i en el ciclo es: 47
# el valor i en el ciclo es: 49
# el valor i en el ciclo es: 51
# el valor i en el ciclo es: 53
# el valor i en el ciclo es: 55
# el valor i en el ciclo es: 57
# el valor i en el ciclo es: 59
# el valor i en el ciclo es: 61
# el valor i en el ciclo es: 63
# el valor i en el ciclo es: 65
# el valor i en el ciclo es: 67
# el valor i en el ciclo es: 69
# el valor i en el ciclo es: 71
# el valor i en el ciclo es: 73
# el valor i en el ciclo es: 75
# el valor i en el ciclo es: 77
# el valor i en el ciclo es: 79
# el valor i en el ciclo es: 81
# el valor i en el ciclo es: 83
# el valor i en el ciclo es: 85
# el valor i en el ciclo es: 87
# el valor i en el ciclo es: 89
# el valor i en el ciclo es: 91
# el valor i en el ciclo es: 93
# el valor i en el ciclo es: 95
# el valor i en el ciclo es: 97
# el valor i en el ciclo es: 99
# el valor i en el ciclo es: 2
# el valor i en el ciclo es: 4
# el valor i en el ciclo es: 6
# el valor i en el ciclo es: 8
# el valor i en el ciclo es: 10
# el valor i en el ciclo es: 12
# el valor i en el ciclo es: 14
# el valor i en el ciclo es: 16
# el valor i en el ciclo es: 18
# el valor i en el ciclo es: 20
# el valor i en el ciclo es: 22
# el valor i en el ciclo es: 24
# el valor i en el ciclo es: 26
# el valor i en el ciclo es: 28
# el valor i en el ciclo es: 30
# el valor i en el ciclo es: 32
# el valor i en el ciclo es: 34
# el valor i en el ciclo es: 36
# el valor i en el ciclo es: 38
# el valor i en el ciclo es: 40
# el valor i en el ciclo es: 42
# el valor i en el ciclo es: 44
# el valor i en el ciclo es: 46
# el valor i en el ciclo es: 48
# el valor i en el ciclo es: 50
# el valor i en el ciclo es: 52
# el valor i en el ciclo es: 54
# el valor i en el ciclo es: 56
# el valor i en el ciclo es: 58
# el valor i en el ciclo es: 60
# el valor i en el ciclo es: 62
# el valor i en el ciclo es: 64
# el valor i en el ciclo es: 66
# el valor i en el ciclo es: 68
# el valor i en el ciclo es: 70
# el valor i en el ciclo es: 72
# el valor i en el ciclo es: 74
# el valor i en el ciclo es: 76
# el valor i en el ciclo es: 78
# el valor i en el ciclo es: 80
# el valor i en el ciclo es: 82
# el valor i en el ciclo es: 84
# el valor i en el ciclo es: 86
# el valor i en el ciclo es: 88
# el valor i en el ciclo es: 90
# el valor i en el ciclo es: 92
# el valor i en el ciclo es: 94
# el valor i en el ciclo es: 96
# el valor i en el ciclo es: 98
# el valor i en el ciclo es: 100
# el valor i en el ciclo es: 102
# el valor i en el ciclo es: 104
# el valor i en el ciclo es: 106
# el valor i en el ciclo es: 108
# el valor i en el ciclo es: 110
# el valor i en el ciclo es: 112
# el valor i en el ciclo es: 114
# el valor i en el ciclo es: 116
# el valor i en el ciclo es: 118
# el valor i en el ciclo es: 120
# el valor i en el ciclo es: 122
# el valor i en el ciclo es: 124
# el valor i en el ciclo es: 126
# el valor i en el ciclo es: 128
# el valor i en el ciclo es: 130
# el valor i en el ciclo es: 132
# el valor i en el ciclo es: 134
# el valor i en el ciclo es: 136
# el valor i en el ciclo es: 138
# el valor i en el ciclo es: 140
# el valor i en el ciclo es: 142
# el valor i en el ciclo es: 144
# el valor i en el ciclo es: 146
# el valor i en el ciclo es: 148
# el valor i en el ciclo es: 150
# el valor i en el ciclo es: 152
# el valor i en el ciclo es: 154
# el valor i en el ciclo es: 156
# el valor i en el ciclo es: 158
# el valor i en el ciclo es: 160
# el valor i en el ciclo es: 162
# el valor i en el ciclo es: 164
# el valor i en el ciclo es: 166
# el valor i en el ciclo es: 168
# el valor i en el ciclo es: 170
# el valor i en el ciclo es: 172
# el valor i en el ciclo es: 174
# el valor i en el ciclo es: 176
# el valor i en el ciclo es: 178
# el valor i en el ciclo es: 180
# el valor i en el ciclo es: 182
# el valor i en el ciclo es: 184
# el valor i en el ciclo es: 186
# el valor i en el ciclo es: 188
# el valor i en el ciclo es: 190
# el valor i en el ciclo es: 192
# el valor i en el ciclo es: 194
# el valor i en el ciclo es: 196
# el valor i en el ciclo es: 198
# el valor i en el ciclo es: 200
# el valor i en el ciclo es: 202
# el valor i en el ciclo es: 204
# el valor i en el ciclo es: 206
# el valor i en el ciclo es: 208
# el valor i en el ciclo es: 210
# el valor i en el ciclo es: 212
# el valor i en el ciclo es: 214
# el valor i en el ciclo es: 216
# el valor i en el ciclo es: 218
# el valor i en el ciclo es: 220
# el valor i en el ciclo es: 222
# el valor i en el ciclo es: 224
# el valor i en el ciclo es: 226
# el valor i en el ciclo es: 228
# el valor i en el ciclo es: 230
# el valor i en el ciclo es: 232
# el valor i en el ciclo es: 234
# el valor i en el ciclo es: 236
# el valor i en el ciclo es: 238
# el valor i en el ciclo es: 240
# el valor i en el ciclo es: 242
# el valor i en el ciclo es: 244
# el valor i en el ciclo es: 246
# el valor i en el ciclo es: 248
# el valor i en el ciclo es: 250
# el valor i en el ciclo es: 252
# el valor i en el ciclo es: 254
# el valor i en el ciclo es: 256
# el valor i en el ciclo es: 258
# el valor i en el ciclo es: 260
# el valor i en el ciclo es: 262
# el valor i en el ciclo es: 264
# el valor i en el ciclo es: 266
# el valor i en el ciclo es: 268
# el valor i en el ciclo es: 270
# el valor i en el ciclo es: 272
# el valor i en el ciclo es: 274
# el valor i en el ciclo es: 276
# el valor i en el ciclo es: 278
# el valor i en el ciclo es: 280
# el valor i en el ciclo es: 282
# el valor i en el ciclo es: 284
# el valor i en el ciclo es: 286
# el valor i en el ciclo es: 288
# el valor i en el ciclo es: 290
# el valor i en el ciclo es: 292
# el valor i en el ciclo es: 294
# el valor i en el ciclo es: 296
# el valor i en el ciclo es: 298
# el valor i en el ciclo es: 300
# el valor i en el ciclo es: 302
# el valor i en el ciclo es: 304
# el valor i en el ciclo es: 306
# el valor i en el ciclo es: 308
# el valor i en el ciclo es: 310
# el valor i en el ciclo es: 312
# el valor i en el ciclo es: 314
# el valor i en el ciclo es: 316
# el valor i en el ciclo es: 318
# el valor i en el ciclo es: 320
# el valor i en el ciclo es: 322
# el valor i en el ciclo es: 324
# el valor i en el ciclo es: 326
# el valor i en el ciclo es: 328
# el valor i en el ciclo es: 330
# el valor i en el ciclo es: 332
# el valor i en el ciclo es: 334
# el valor i en el ciclo es: 336
# el valor i en el ciclo es: 338
# el valor i en el ciclo es: 340
# el valor i en el ciclo es: 342
# el valor i en el ciclo es: 344
# el valor i en el ciclo es: 346
# el valor i en el ciclo es: 348
# el valor i en el ciclo es: 350
# el valor i en el ciclo es: 352
# el valor i en el ciclo es: 354
# el valor i en el ciclo es: 356
# el valor i en el ciclo es: 358
# el valor i en el ciclo es: 360
# el valor i en el ciclo es: 362
# el valor i en el ciclo es: 364
# el valor i en el ciclo es: 366
# el valor i en el ciclo es: 368
# el valor i en el ciclo es: 370
# el valor i en el ciclo es: 372
# el valor i en el ciclo es: 374
# el valor i en el ciclo es: 376
# el valor i en el ciclo es: 378
# el valor i en el ciclo es: 380
# el valor i en el ciclo es: 382
# el valor i en el ciclo es: 384
# el valor i en el ciclo es: 386
# el valor i en el ciclo es: 388
# el valor i en el ciclo es: 390
# el valor i en el ciclo es: 392
# el valor i en el ciclo es: 394
# el valor i en el ciclo es: 396
# el valor i en el ciclo es: 398
# el valor i en el ciclo es: 400
# el valor i en el ciclo es: 402
# el valor i en el ciclo es: 404
# el valor i en el ciclo es: 406
# el valor i en el ciclo es: 408
# el valor i en el ciclo es: 410
# el valor i en el ciclo es: 412
# el valor i en el ciclo es: 414
# el valor i en el ciclo es: 416
# el valor i en el ciclo es: 418
# el valor i en el ciclo es: 420
# el valor i en el ciclo es: 422
# el valor i en el ciclo es: 424
# el valor i en el ciclo es: 426
# el valor i en el ciclo es: 428
# el valor i en el ciclo es: 430
# el valor i en el ciclo es: 432
# el valor i en el ciclo es: 434
# el valor i en el ciclo es: 436
# el valor i en el ciclo es: 438
# el valor i en el ciclo es: 440
# el valor i en el ciclo es: 442
# el valor i en el ciclo es: 444
# el valor i en el ciclo es: 446
# el valor i en el ciclo es: 448
# el valor i en el ciclo es: 450
# el valor i en el ciclo es: 452
# el valor i en el ciclo es: 454
# el valor i en el ciclo es: 456
# el valor i en el ciclo es: 458
# el valor i en el ciclo es: 460
# el valor i en el ciclo es: 462
# el valor i en el ciclo es: 464
# el valor i en el ciclo es: 466
# el valor i en el ciclo es: 468
# el valor i en el ciclo es: 470
# el valor i en el ciclo es: 472
# el valor i en el ciclo es: 474
# el valor i en el ciclo es: 476
# el valor i en el ciclo es: 478
# el valor i en el ciclo es: 480
# el valor i en el ciclo es: 482
# el valor i en el ciclo es: 484
# el valor i en el ciclo es: 486
# el valor i en el ciclo es: 488
# el valor i en el ciclo es: 490
# el valor i en el ciclo es: 492
# el valor i en el ciclo es: 494
# el valor i en el ciclo es: 496
# el valor i en el ciclo es: 498
# el valor i en el ciclo es: 500
# el valor i en el ciclo es: 502
# el valor i en el ciclo es: 504
# el valor i en el ciclo es: 506
# el valor i en el ciclo es: 508
# el valor i en el ciclo es: 510
# el valor i en el ciclo es: 512
# el valor i en el ciclo es: 514
# el valor i en el ciclo es: 516
# el valor i en el ciclo es: 518
# el valor i en el ciclo es: 520
# el valor i en el ciclo es: 522
# el valor i en el ciclo es: 524
# el valor i en el ciclo es: 526
# el valor i en el ciclo es: 528
# el valor i en el ciclo es: 530
# el valor i en el ciclo es: 532
# el valor i en el ciclo es: 534
# el valor i en el ciclo es: 536
# el valor i en el ciclo es: 538
# el valor i en el ciclo es: 540
# el valor i en el ciclo es: 542
# el valor i en el ciclo es: 544
# el valor i en el ciclo es: 546
# el valor i en el ciclo es: 548
# el valor i en el ciclo es: 550
# el valor i en el ciclo es: 552
# el valor i en el ciclo es: 554
# el valor i en el ciclo es: 556
# el valor i en el ciclo es: 558
# el valor i en el ciclo es: 560
# el valor i en el ciclo es: 562
# el valor i en el ciclo es: 564
# el valor i en el ciclo es: 566
# el valor i en el ciclo es: 568
# el valor i en el ciclo es: 570
# el valor i en el ciclo es: 572
# el valor i en el ciclo es: 574
# el valor i en el ciclo es: 576
# el valor i en el ciclo es: 578
# el valor i en el ciclo es: 580
# el valor i en el ciclo es: 582
# el valor i en el ciclo es: 584
# el valor i en el ciclo es: 586
# el valor i en el ciclo es: 588
# el valor i en el ciclo es: 590
# el valor i en el ciclo es: 592
# el valor i en el ciclo es: 594
# el valor i en el ciclo es: 596
# el valor i en el ciclo es: 598
# el valor i en el ciclo es: 600
# el valor i en el ciclo es: 602
# el valor i en el ciclo es: 604
# el valor i en el ciclo es: 606
# el valor i en el ciclo es: 608
# el valor i en el ciclo es: 610
# el valor i en el ciclo es: 612
# el valor i en el ciclo es: 614
# el valor i en el ciclo es: 616
# el valor i en el ciclo es: 618
# el valor i en el ciclo es: 620
# el valor i en el ciclo es: 622
# el valor i en el ciclo es: 624
# el valor i en el ciclo es: 626
# el valor i en el ciclo es: 628
# el valor i en el ciclo es: 630
# el valor i en el ciclo es: 632
# el valor i en el ciclo es: 634
# el valor i en el ciclo es: 636
# el valor i en el ciclo es: 638
# el valor i en el ciclo es: 640
# el valor i en el ciclo es: 642
# el valor i en el ciclo es: 644
# el valor i en el ciclo es: 646
# el valor i en el ciclo es: 648
# el valor i en el ciclo es: 650
# el valor i en el ciclo es: 652
# el valor i en el ciclo es: 654
# el valor i en el ciclo es: 656
# el valor i en el ciclo es: 658
# el valor i en el ciclo es: 660
# el valor i en el ciclo es: 662
# el valor i en el ciclo es: 664
# el valor i en el ciclo es: 666
# el valor i en el ciclo es: 668
# el valor i en el ciclo es: 670
# el valor i en el ciclo es: 672
# el valor i en el ciclo es: 674
# el valor i en el ciclo es: 676
# el valor i en el ciclo es: 678
# el valor i en el ciclo es: 680
# el valor i en el ciclo es: 682
# el valor i en el ciclo es: 684
# el valor i en el ciclo es: 686
# el valor i en el ciclo es: 688
# el valor i en el ciclo es: 690
# el valor i en el ciclo es: 692
# el valor i en el ciclo es: 694
# el valor i en el ciclo es: 696
# el valor i en el ciclo es: 698
# el valor i en el ciclo es: 700
# el valor i en el ciclo es: 702
# el valor i en el ciclo es: 704
# el valor i en el ciclo es: 706
# el valor i en el ciclo es: 708
# el valor i en el ciclo es: 710
# el valor i en el ciclo es: 712
# el valor i en el ciclo es: 714
# el valor i en el ciclo es: 716
# el valor i en el ciclo es: 718
# el valor i en el ciclo es: 720
# el valor i en el ciclo es: 722
# el valor i en el ciclo es: 724
# el valor i en el ciclo es: 726
# el valor i en el ciclo es: 728
# el valor i en el ciclo es: 730
# el valor i en el ciclo es: 732
# el valor i en el ciclo es: 734
# el valor i en el ciclo es: 736
# el valor i en el ciclo es: 738
# el valor i en el ciclo es: 740
# el valor i en el ciclo es: 742
# el valor i en el ciclo es: 744
# el valor i en el ciclo es: 746
# el valor i en el ciclo es: 748
# el valor i en el ciclo es: 750
# el valor i en el ciclo es: 752
# el valor i en el ciclo es: 754
# el valor i en el ciclo es: 756
# el valor i en el ciclo es: 758
# el valor i en el ciclo es: 760
# el valor i en el ciclo es: 762
# el valor i en el ciclo es: 764
# el valor i en el ciclo es: 766
# el valor i en el ciclo es: 768
# el valor i en el ciclo es: 770
# el valor i en el ciclo es: 772
# el valor i en el ciclo es: 774
# el valor i en el ciclo es: 776
# el valor i en el ciclo es: 778
# el valor i en el ciclo es: 780
# el valor i en el ciclo es: 782
# el valor i en el ciclo es: 784
# el valor i en el ciclo es: 786
# el valor i en el ciclo es: 788
# el valor i en el ciclo es: 790
# el valor i en el ciclo es: 792
# el valor i en el ciclo es: 794
# el valor i en el ciclo es: 796
# el valor i en el ciclo es: 798
# el valor i en el ciclo es: 800
# el valor i en el ciclo es: 802
# el valor i en el ciclo es: 804
# el valor i en el ciclo es: 806
# el valor i en el ciclo es: 808
# el valor i en el ciclo es: 810
# el valor i en el ciclo es: 812
# el valor i en el ciclo es: 814
# el valor i en el ciclo es: 816
# el valor i en el ciclo es: 818
# el valor i en el ciclo es: 820
# el valor i en el ciclo es: 822
# el valor i en el ciclo es: 824
# el valor i en el ciclo es: 826
# el valor i en el ciclo es: 828
# el valor i en el ciclo es: 830
# el valor i en el ciclo es: 832
# el valor i en el ciclo es: 834
# el valor i en el ciclo es: 836
# el valor i en el ciclo es: 838
# el valor i en el ciclo es: 840
# el valor i en el ciclo es: 842
# el valor i en el ciclo es: 844
# el valor i en el ciclo es: 846
# el valor i en el ciclo es: 848
# el valor i en el ciclo es: 850
# el valor i en el ciclo es: 852
# el valor i en el ciclo es: 854
# el valor i en el ciclo es: 856
# el valor i en el ciclo es: 858
# el valor i en el ciclo es: 860
# el valor i en el ciclo es: 862
# el valor i en el ciclo es: 864
# el valor i en el ciclo es: 866
# el valor i en el ciclo es: 868
# el valor i en el ciclo es: 870
# el valor i en el ciclo es: 872
# el valor i en el ciclo es: 874
# el valor i en el ciclo es: 876
# el valor i en el ciclo es: 878
# el valor i en el ciclo es: 880
# el valor i en el ciclo es: 882
# el valor i en el ciclo es: 884
# el valor i en el ciclo es: 886
# el valor i en el ciclo es: 888
# el valor i en el ciclo es: 890
# el valor i en el ciclo es: 892
# el valor i en el ciclo es: 894
# el valor i en el ciclo es: 896
# el valor i en el ciclo es: 898
# el valor i en el ciclo es: 900
# el valor i en el ciclo es: 902
# el valor i en el ciclo es: 904
# el valor i en el ciclo es: 906
# el valor i en el ciclo es: 908
# el valor i en el ciclo es: 910
# el valor i en el ciclo es: 912
# el valor i en el ciclo es: 914
# el valor i en el ciclo es: 916
# el valor i en el ciclo es: 918
# el valor i en el ciclo es: 920
# el valor i en el ciclo es: 922
# el valor i en el ciclo es: 924
# el valor i en el ciclo es: 926
# el valor i en el ciclo es: 928
# el valor i en el ciclo es: 930
# el valor i en el ciclo es: 932
# el valor i en el ciclo es: 934
# el valor i en el ciclo es: 936
# el valor i en el ciclo es: 938
# el valor i en el ciclo es: 940
# el valor i en el ciclo es: 942
# el valor i en el ciclo es: 944
# el valor i en el ciclo es: 946
# el valor i en el ciclo es: 948
# el valor i en el ciclo es: 950
# el valor i en el ciclo es: 952
# el valor i en el ciclo es: 954
# el valor i en el ciclo es: 956
# el valor i en el ciclo es: 958
# el valor i en el ciclo es: 960
# el valor i en el ciclo es: 962
# el valor i en el ciclo es: 964
# el valor i en el ciclo es: 966
# el valor i en el ciclo es: 968
# el valor i en el ciclo es: 970
# el valor i en el ciclo es: 972
# el valor i en el ciclo es: 974
# el valor i en el ciclo es: 976
# el valor i en el ciclo es: 978
# el valor i en el ciclo es: 980
# el valor i en el ciclo es: 982
# el valor i en el ciclo es: 984
# el valor i en el ciclo es: 986
# el valor i en el ciclo es: 988
# el valor i en el ciclo es: 990
# el valor i en el ciclo es: 992
# el valor i en el ciclo es: 994
# el valor i en el ciclo es: 996
# el valor i en el ciclo es: 998
# el valor i en el ciclo es: 1000

# %% [markdown]
# ### ejercicio 3

# %%
n = int(input("Ingrese numero natural mayor a 2: ")) #le pide al usuario que ingrese un numero que sea mayor de dos
if n < 2: #verifica que el numero sea menor de dos, de lo contrario funcionara la condicion sera falsa y se ejecutara la otra
    print("el numero debe ser mayor o igual a dos") #imprime indicandole al usuario que el numero debe ser mayor
else: #se verifica esta condicion 
    for i in range (n, 1, -1): #n es el valor inicial de la secuencia, 1 es el valor final de la lista que sera 2 y -1 sera lo que define la descendencia en la lista y los pasos
        if i%2 != 0: #exceptua todos los qeu son impares
            continue
    print(("el valor en el ciclo es: " + str(i))) #<bloque> verifica si el numero es impar y lo exceptua
# Out:
# el valor en el ciclo es: 24
# el valor en el ciclo es: 22
# el valor en el ciclo es: 20
# el valor en el ciclo es: 18
# el valor en el ciclo es: 16
# el valor en el ciclo es: 14
# el valor en el ciclo es: 12
# el valor en el ciclo es: 10
# el valor en el ciclo es: 8
# el valor en el ciclo es: 6
# el valor en el ciclo es: 4
# el valor en el ciclo es: 2

# %% [markdown]
# ### ejercicio 4

# %%
n = int(input("Ingrese numero natural: ")) #el usuario ingresa el numero
for i in range(1, n + 1): #itere el rango de uno hasta n, para cada elemento de i
        factorial = 1 #estableci la variable del numero del factorial
        for j in range(1, i + 1): #itere el rango desde 1 hasta los elementos de i, para cada elemnto de j
            factorial *= j #multiplice el factorial para cada elemento j
print("el factorial de su numero " + str(n)+ " es: " + str(factorial)) #imprimi el numero y su factorial
# Out:
# el factorial de su numero 7 es: 5040

# %% [markdown]
# ### ejercicio 5

# %%
print("programa para calcular el resultado del numero 2 a una potencia dada")
potencia = int(input("Ingrese numero natural: ")) #el usuario ingresa el numero
resultado:int = 1 #defini la variable resultado con un valor de 1
for i in range(potencia): #se itera el valor del numero n dado para cada elemento de i
    resultado *= 2 #eleva a 2 por el numero dado
print("el numero 2 elevado a " +str(potencia)+ " es: " +str(resultado)) #imprime los resultados
# Out:
# programa para calcular el resultado del numero 2 a una potencia dada
# el numero 2 elevado a 7 es: 128

# %% [markdown]
# ### ejercicio 6

# %%
n = int(input("ingrese la potencia, un numero natural: ")) #el usuario indica la potencia
x = float(input("ingrese un numero real: ")) #el usuario indica el numero a elevar con la potencia dada
resultado:float = 1.0 #defini la variable con 1 en flotante 
print("el numero " +str(x)+ " elevado al numero " + str(n)+ " es: ") #se imprime los valores dados para luego dar el resultado
for i in range(n): #se intera los valores 0 a n dado para cada elemento de i
    resultado *= x #se eleva x dado por el numero n dado
print(resultado) #imprime el resultado
# Out:
# el numero 3.5 elevado al numero 7 es:
# 6433.9296875

# %% [markdown]
# ### ejercicio 7

# %%
for i in range(1, 10): #establezco el rango para los elementos de i de 1 a 9
    print("Tabla de multiplicar del: " + str(i)) #imprimo el numero de la tabla de multiplicar de la lista i se itera hasta que se termine el rango de i dado
    for j in range(1, 11): #establezco el rango de j de 1 a 10 
        resultado = i * j #multiplico el numero de la lista i por el numero de la lista j 
        print(str(i)+ " x " + str(j)+ " = " + str(resultado)) #imprimo el resultado se itera hasta finalizar el rango de la lista j 
    print()
# Out:
# Tabla de multiplicar del: 1
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
#
# Tabla de multiplicar del: 2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
#
# Tabla de multiplicar del: 3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
#
# Tabla de multiplicar del: 4
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
#
# Tabla de multiplicar del: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
#
# Tabla de multiplicar del: 6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
#
# Tabla de multiplicar del: 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
#
# Tabla de multiplicar del: 8
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80
#
# Tabla de multiplicar del: 9
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %% [markdown]
# ### ejercicio 8

# %%
import math #importe la funcion math para luego poder implementarla

def aproximacion_exponencial(x, n): #defini la aproximacion exponencial con los argumentos x y n 
    aproximacion = 0 #estableci la variable aproximacion con un valor de 0
    
    for i in range(n): #se intera los valores 0 a n dado para cada elemento de i
        termino = (x ** i) / math.factorial(i) #calcule la ecuacion dada por taylor para la funcion exponencial
        aproximacion += termino #sume la aproximacion con el termino segun los terminos dados n y asi calcular la aproximacion con la formula de taylor 
    
    return aproximacion #retorna la aproximacion
# Calcular la aproximación de la función exponencial para x = 0.9, utilizando los primeros 7 términos de la serie de Maclaurin
x:float = 0.9
n:int = 7
while True: #use el ciclo while para que luego este cumpla la funcion if
  aproximacion = aproximacion_exponencial(x, n) #llame la funcion def para luego imprimirla y para hallar el error
  error = abs(valor_real - aproximacion) #calcule el error con el valor real restando a la aproximacion hayada y use la funcion abs para que lo calcule con el valor absoluto
  # Imprimir la diferencia si es menor del 0.1% de lo contrario no se ejecutara el programa ya que no se podra imprimir la cadena
  if error < 0.001: 
     break
  valor_real = math.exp(x) #se haya el valor real para luego imprimirlo
porcentaje = error * 100 #multiplice el erro por 100 para darlo en porcentaje
cadena = "{:.2f}%".format(porcentaje) #lo puse en un cadena de solo dos decimales 
print("el valor real es de: " + str(valor_real)) #imprime el valor real
print("la aproximacion es de: " + str(aproximacion)+ " y un error de: "+ str(cadena)) # imprime la aproximacion y el error
# Out:
# el valor real es de: 2.45960311115695
# la aproximacion es de: 2.4594963625 y un error de: 0.01%

# %% [markdown]
# ### ejercicio 9

# %%
import math #importe la funcion math para luego poder implementarla

def aproximacion_seno(x, n): #defini la aproximacion seno con los argumentos x y n 
    aproximacion = 0 #estableci la variable aproximacion con un valor de 0
    
    for i in range(n): #se itera los valores 0 a n dado para cada elemento de i
        termino = ((-1) ** i) * (x ** (2 * i + 1)) / math.factorial(2 * i + 1) #calcule la ecuacion dada por taylor para la funcion seno
        aproximacion += termino #sume la aproximacion con el termino segun los terminos dados n y asi calcular la aproximacion con la formula de taylor 
    
    return aproximacion #retorna la aproximacion
# Calcular la aproximación de la función exponencial para x = 3.5, utilizando los primeros 7 términos de la serie de Maclaurin
x:float = 3.5
n:int = 7
while True: #use el ciclo while para que luego este cumpla la funcion if
  aproximacion = aproximacion_seno(x, n) #llame la funcion def para luego imprimirla y para hallar el error
  error = abs(valor_real - aproximacion) #calcule el error con el valor real restando a la aproximacion hayada y use la funcion abs para que lo calcule con el valor absoluto
  # Imprimir la diferencia si es menor del 0.1% de lo contrario no se ejecutara el programa ya que no se podra imprimir la cadena
  if error < 0.001: 
     break
  valor_real = math.sin(x) #se haya el valor real para luego imprimirlo
porcentaje = error * 100 #multipliquee el error por 100 para darlo en porcentaje
cadena = "{:.2f}%".format(porcentaje) #lo puse en un cadena de solo dos decimales 
print("el valor real es de: " + str(valor_real)) #imprime el valor real
print("la aproximacion es de: " + str(aproximacion)+ " y un error de: "+ str(cadena)) # imprime la aproximacion y el error
# Out:
# el valor real es de: -0.35078322768961984
# la aproximacion es de: -0.35067724867955763 y un error de: 0.01%

# %% [markdown]
# ### ejercicio 10

# %%
import math #importe la funcion math para luego poder implementarla

def aproximacion_arctan(x, n): #defini la aproximacion arcontangente con los argumentos x y n 
    if abs(x) > 1:
        return None  # La serie de Maclaurin de arctan es válida solo para valores |x| <= 1

    aproximacion = 0 #estableci la variable aproximacion con un valor de 0
    
    for i in range(n): #se itera los valores 0 a n dado para cada elemento de i
        termino = ((-1) ** i) * (x ** (2 * i + 1)) / (2 * i + 1) #calcule la ecuacion dada por taylor para la funcion seno
        aproximacion += termino #sume la aproximacion con el termino segun los terminos dados n y asi calcular la aproximacion con la formula de taylor 
    
    return aproximacion #retorna la aproximacion
# Calcular la aproximación de la función exponencial para x = 0.7, utilizando los primeros 7 términos de la serie de Maclaurin
x:float = 0.7
n:int = 7
while True: #use el ciclo while para que luego este cumpla la funcion if
  aproximacion = aproximacion_arctan(x, n) #llame la funcion def para luego imprimirla y para hallar el error
  error = abs(valor_real - aproximacion) #calcule el error con el valor real restando a la aproximacion hayada y use la funcion abs para que lo calcule con el valor absoluto
  # Imprimir la diferencia si es menor del 0.1% de lo contrario no se ejecutara el programa ya que no se podra imprimir la cadena
  if error < 0.001: 
     break
  valor_real = math.atan(x) #se haya el valor real para luego imprimirlo
porcentaje = error * 100 #multipliquee el error por 100 para darlo en porcentaje
cadena = "{:.2f}%".format(porcentaje) #lo puse en un cadena de solo dos decimales 
print("el valor real es de: " + str(valor_real)) #imprime el valor real
print("la aproximacion es de: " + str(aproximacion)+ " y un error de: "+ str(cadena)) # imprime la aproximacion y el error
# Out:
# el valor real es de: 0.6107259643892086
# la aproximacion es de: 0.6109472310914681 y un error de: 0.02%
